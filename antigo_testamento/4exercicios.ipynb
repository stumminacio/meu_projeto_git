# %%
numero = int(input("digite um numero de 1 a 12: "))

meses = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]

print(meses[numero - 1])
# Out:
# digite um numero de 1 a 127
# July

# %%
valores = [4, 4.5, 5, 2, 1.5 ]

pedido1 = int(input("seu primeiro pedido: "))
pedido2 = int(input("seu segundo pedido: "))

valor1 = valores[pedido1 - 1]
valor2 = valores[pedido2 - 1]

valor_final = valor1 + valor2

print(valor_final)
# Out:
# seu primeiro pedido: 1
# seu segundo pedido: 2
# 8.5
