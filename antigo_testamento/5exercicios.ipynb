# %%
# Faça um programa que recebe um número de 1 a 10 e imprime a tabuada desse número.
# Faça um programa que recebe do usuário 10 valores de números inteiros, armazena em um vetor e após percorrê-lo exibe qual é o maior valor e a sua posição.

numero = int(input("digite seu numero: "))

for i in range(1, 11):
  print(f"{numero} * {i} = {numero * i}")
# Out:
# digite seu numero: 2
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20

# %%
V = []

for i in range(10):
  numero = int(input("numeros da lista: "))
  V.append(numero)

maior_valor = V[0]

for i in range(10):
  if V[i] > maior_valor:
    maior_valor = V[i]
    posicao_maior = i

print(V)
print(f"maior valor = {maior_valor}")
print(f"posicao = {posicao_maior}")
# Out:
# numeros da lista: 1
# numeros da lista: 2
# numeros da lista: 3
# numeros da lista: 11
# numeros da lista: 4
# numeros da lista: 6
# numeros da lista: 7
# numeros da lista: 8
# numeros da lista: 9
# numeros da lista: 10
# [1, 2, 3, 11, 4, 6, 7, 8, 9, 10]
# maior valor = 11
# posicao = 3

# %%
# fibonacci
# A sequência de números 0 1 1 2 3 5 8 13 21... é conhecida como série de Fibonacci.
# Nesta sequência, cada número, depois dos 2 primeiros, é igual à soma dos 2 anteriores.
# Escreva um algoritmo que leia um inteiro N (N < 46) e mostre os N primeiros números dessa série.

V = [0, int(input("primeiro numero da sequencia: "))]


for i in range(10):
  V_a1 = V[-1] + V[-2]
  V.append(V_a1)

print(V)
# Out:
# primeiro numero da sequencia: 45
# [0, 45, 45, 90, 135, 225, 360, 585, 945, 1530, 2475, 4005]
