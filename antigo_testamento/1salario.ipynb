# %%
#entrada/input
numero_funcionario = int(input("digite o numero do funcionario: "))
#ver se o funcionario existe
while numero_funcionario > 3:
  print("numero invalido, tente novamente!")
  numero_funcionario = int(input("digite o numero do funcionario: "))
horas_trabalhadas = int(input("digite a quantidade de horas trabalhadas: "))
valor_hora = float(input("digite o valor da hora: "))

#calculo
salario = horas_trabalhadas * valor_hora

#saida/output
print(f"numero funcionario: {numero_funcionario}")
print(f"salario R$: {salario: .2f}")
# Out:
# digite o numero do funcionario: 1
# digite a quantidade de horas trabalhadas: 14
# digite o valor da hora: 567
# numero funcionario: 1
# salario R$:  7938.00

# %%
#versão original

#entrada de dados/input
numero_funcionario = int(input("digite o numero do funcionario: "))
horas_trabalhadas = int(input("digite a quantidade de horas trabalhadas: "))
valor_hora = float(input("digite o valor da hora: "))

#calculo
salario = horas_trabalhadas * valor_hora

#saida de dados/output
print(f"numero funcionario: {numero_funcionario}")
print(f"salario R$: {salario: .2f}")
# Out:
# digite o numero do funcionario: 1
# digite a quantidade de horas trabalhadas: 23
# digite o valor da hora: 4
# numero funcionario: 1
# salario R$:  92.00
