# %%
import random

jogador = input("seu nome = ")
opcoes = ["pedra", "papel", "tesoura"]
opcao_jogador = input("escolha entre pedra, papel ou tesoura: ")
opcao_computador = random.choice(opcoes)

if opcao_jogador == opcao_computador:
  print(jogador, "= ", opcao_jogador)
  print("computador = ", opcao_computador)
  print("empate")

elif opcao_jogador == "pedra" and opcao_computador == "tesoura":
  print(jogador, "= ", opcao_jogador)
  print("computador = ", opcao_computador)
  print("jogador", jogador, "venceu com =", opcao_jogador)

elif opcao_jogador == "papel" and opcao_computador == "pedra":
  print(jogador, "= ", opcao_jogador)
  print("computador = ", opcao_computador)
  print("jogador", jogador, "venceu com =", opcao_jogador)

elif opcao_jogador == "tesoura" and opcao_computador == "papel":
  print(jogador, "= ", opcao_jogador)
  print("computador = ", opcao_computador)
  print("jogador", jogador, "venceu com =", opcao_jogador)

elif opcao_jogador == "tesoura" and opcao_computador == "pedra":
  print(jogador, "= ", opcao_jogador)
  print("computador = ", opcao_computador)
  print("computador venceu com =", opcao_computador)

elif opcao_jogador == "pedra" and opcao_computador == "papel":
  print(jogador, "= ", opcao_jogador)
  print("computador = ", opcao_computador)
  print("computador venceu com =", opcao_computador)

elif opcao_jogador == "papel" and opcao_computador == "tesoura":
  print(jogador, "= ", opcao_jogador)
  print("computador = ", opcao_computador)
  print("computador venceu com =", opcao_computador)
# Out:
# seu nome = inacio
# escolha entre pedra, papel ou tesoura: pedra
# inacio =  pedra
# computador =  papel
# computador venceu com = papel

# %%
import random

jogador = input("seu nome = ")
opcoes = ["pedra", "papel", "tesoura"]
opcao_jogador = input("escolha entre pedra, papel ou tesoura: ")
opcao_computador = random.choice(opcoes)

if opcao_jogador == opcao_computador:
  print(jogador, "= ", opcao_jogador)
  print("computador = ", opcao_computador)
  print("empate")

elif opcao_jogador == "pedra" and opcao_computador == "tesoura" or \
     opcao_jogador == "papel" and opcao_computador == "pedra" or \
     opcao_jogador == "tesoura" and opcao_computador == "papel":
      print(jogador, "= ", opcao_jogador)
      print("computador = ", opcao_computador)
      print("jogador", jogador, "venceu com =", opcao_jogador)

else:
  print(jogador, "= ", opcao_jogador)
  print("computador = ", opcao_computador)
  print("computador venceu com =", opcao_computador)
# Out:
# seu nome = anom
# escolha entre pedra, papel ou tesoura: pedra
# anom =  pedra
# computador =  tesoura
# jogador anom venceu com = pedra

# %%
print("dado:", random.randint(1, 20))
# Out:
# dado: 6

# %%
#sistema escolar

aluno = input("digite o seu nome: ")
nota = float(input("digite sua nota: "))

if nota >= 7:
  print("aprovado")
elif nota >= 5:
  print("recuperação")
else:
  print("reprovado")
# Out:
# digite o seu nome: inacio
# digite sua nota: 8.5
# aprovado
