# %%
'''
1. Escreva uma função chamada cidadeEPais() que recebe como parâmetro um nome de uma cidade e de um país.
A função deve exibir uma frase simples, como “Brasília está localizada no Brasil”.
Forneça um valor default ao parâmetro que representa o país.
Chame sua função para três cidades diferentes, de modo que pelo menos uma delas não esteja no país default.

2. Crie uma função que utilize a função velocidade() da imagem 04 da apostila e
retorne quem entre dois amigos é o mais rápido.
Lembrando que a função velocidade() tem como parâmetro uma distância e um tempo,
altere as chamadas a seguir para que todas produzam a mesma saída:
velocidade(10,1000)
velocidade(10)
velocidade(1000,10)
'''

# %%
# 1 desafio

def cidadeEpais(cidade, pais = "Brasil"):
  print(f"A cidade {cidade} está situada no país {pais}")

cidadeEpais()
# Out:
# A cidade brasilia está situada no país Brasil

# %%
# 2 exercicio\
# Não entendi esse exercicio, deve estar errado KKKKK

def velocidade(distancia, tempo=10):
    vel_med = distancia / tempo
    return vel_med  # Devolve o valor calculado

amigo1_vel = velocidade(
    int(input("Qual a distancia do primeiro? ")),
    int(input("Qual o tempo do primeiro? ")),
)

amigo2_vel = velocidade(
    int(input("Qual a distancia do segundo? ")),
    int(input("Qual o tempo do segundo? ")),
)

def verificar_maior(vel1, vel2):
    if vel1 > vel2:
        print("O amigo 1 é mais rápido!")
    elif vel2 > vel1:
        print("O amigo 2 é mais rápido!")
    else:
        print("Ambos possuem a mesma velocidade!")

verificar_maior(amigo1_vel, amigo2_vel)
# Out:
# Qual a distancia do primeiro? 1000
# Qual o tempo do primeiro? 10
# Qual a distancia do segundo? 10
# Qual o tempo do segundo? 1000
# O amigo 1 é mais rápido!

# %%
'''
Aqui seria o segundo exercicio,
nao vou coloca-lo aqui pois ele é mt pequeno
'''
L = []

for i in range(3):
  numero = int(input("qual sera seus numeros? "))
  L.append(numero)

maior = L[0]

for i in range(3):
  if L[i] > i:
    maior = L[i]

print(L)
print(f"{maior} eh o maior")
# Out:
# qual sera seus numeros? 1
# qual sera seus numeros? 42
# qual sera seus numeros? 2
# [1, 42, 2]
# 42 eh o maior

# %%
'''
Leia um valor inteiro. A seguir, calcule o menor número
de notas possíveis (cédulas) no qual o valor pode ser decomposto.
As notas consideradas são de 100, 50, 20, 10, 5, 2 e 1.
A seguir, mostre o valor lido e a relação de notas necessárias.
'''

valor = int(input("qual sera o valor inicial? "))

valor_inicial = valor

notas = [100, 50, 20, 10, 5, 1]

for nota in notas:
  qnt_notas = valor // nota
  valor = valor % nota
  print(f"{qnt_notas} = notas des R${nota}")
# Out:
# qual sera o valor inicial? 372
# 3 = notas des R$100
# 1 = notas des R$50
# 1 = notas des R$20
# 0 = notas des R$10
# 0 = notas des R$5
# 2 = notas des R$1
