# %%
# Faça um programa que leia 5 valores inteiros. Conte quantos destes valores digitados são pares e mostre esta informação.

valores = []
qntd_valores = 0

for i in range(5):
  valor_add = int(input("qual valor quer adicionar? "))
  valores.append(valor_add)

for i in range(5):
  if valores[i] % 2 == 0:
    valor = valores[i]
    qntd_valores = qntd_valores + 1
    print(valor)

print(valores)
# Out:
# qual valor quer adicionar? 2
# qual valor quer adicionar? 4
# qual valor quer adicionar? 6
# qual valor quer adicionar? 7
# qual valor quer adicionar? 8
# 2
# 4
# 6
# 8
# [2, 4, 6, 7, 8]

# %%
# Leia um valor inteiro X. Em seguida apresente os 6 valores ímpares consecutivos a partir de X, um valor por linha, inclusive o X se for o caso.

x = int(input("qual sera o valor? "))

valores = []

if x % 2 != 0:
  valores.append(x)

while len(valores) != 6:
  if len(valores) == 1:
    for i in range(5):
      x = x + 2
      valores.append(x)
  else:
    x = x + 1
    for i in range(6):
      valores.append(x)
      x = x + 2

atual = valores[0]

for i in valores:
  print(i, '\n')
# Out:
# qual sera o valor? 23
# 23
#
# 25
#
# 27
#
# 29
#
# 31
#
# 33
