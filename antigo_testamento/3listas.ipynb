# %%
# variaveis

fruta1 = "Maça"
fruta2 = "Banana"
fruta3 = "Laranja"

# %%
dados = ["Carlos", 25, True, 1.75]

# %%
# listas
fruteira = ["Maça", "Banana", "Laranja"]
cores = ["azul", "vermelho", "verde", "amarelo", "roxo"]
nomes = ["Inácio", "Edney", "João", "marcelo", "Clara"]
cadastrados = ["Luciano"]

# %%
# adicionar ao final da lista

nomes.append("Ricardo")
cores.append("ciano")

print(nomes[-1], cores[-1])
# Out:
# Ricardo ciano

# %%
# adicionar à um lugar especifico

cores.insert(2, "branco")

print(cores)
# Out:
# ['azul', 'vermelho', 'branco', 'verde', 'amarelo', 'roxo', 'ciano']

# %%
# remove algo da lista
# usando o index
# cores.remove(cores[2])
# usando o valor
cores.remove("ciano")

print(cores)
# Out:
# ['azul', 'vermelho', 'branco', 'verde', 'amarelo', 'roxo']

# %%
# conta a quantidade de itens em uma lista

print(len(cores))
# Out:
# 6

# %%
cadastrados.append(input("qual seu nome? "))

print(cadastrados)

cadastrados.remove(cadastrados[-1])
# Out:
# qual seu nome? Inácio
# ['Luciano', 'Inácio']
